# %%
import os
import pandas as pd

# %%
df_stat = pd.DataFrame({'Tahun' : [2001,2002,2003, 2004, 2005, 2006, 2007, 2008], 
                        'AVANZA'  : [137,146,146,98,51,144, 89,106],
                        'XENIA' : [86,118,125,60,50,150,118,113],})

# %%
df_stat
# Out:
#    Tahun  AVANZA  XENIA
# 0   2001     137     86
# 1   2002     146    118
# 2   2003     146    125
# 3   2004      98     60
# 4   2005      51     50
# 5   2006     144    150
# 6   2007      89    118
# 7   2008     106    113

# %%
mean_avanza = df_stat['AVANZA'].mean()
mean_avanza
# Out:
# 114.625

# %%
## print("Nilai rata-rata penjualan selama 8 tahun adalah "+mean_avanza)

# %%
import statistics

print("Nilai varian dari AVANZA selama 8 tahun adalah", statistics.variance(df_stat['AVANZA']))
# Out:
# Nilai varian dari AVANZA selama 8 tahun adalah 1198.267857142857

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive'

# %%
house_prices = pd.read_csv(os.path.join(path, "house_prices.csv"), usecols = ["BsmtUnfSF", "MSSubClass", "GarageArea"])

# %%
house_prices.head(10)
# Out:
#    MSSubClass  BsmtUnfSF  GarageArea
# 0          60        150         548
# 1          20        284         460
# 2          60        434         608
# 3          70        540         642
# 4          60        490         836
# 5          50         64         480
# 6          20        317         636
# 7          60        216         484
# 8          50        952         468
# 9         190        140         205

# %%
house_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MSSubClass  1460 non-null   int64
#  1   BsmtUnfSF   1460 non-null   int64
#  2   GarageArea  1460 non-null   int64
# dtypes: int64(3)
# memory usage: 34.3 KB

# %%
house_prices['MSSubClass'].describe()
# Out:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.pyplot import subplot

# %%
f,ax = plt.subplots(figsize=(25,15))
sns.heatmap(house_prices.corr(), annot = True, linewidths=0.5, linecolor="red", fmt='.1f', ax=ax)
plt.show()
